# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshika14168/python_projects/blob/main/password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# generate a random password of 8 digit
import random
password=random.randint(10000000,99999999)
print("Random password of 8-digit is...")
print(password)
# Out:
# Random password of 8-digit is...
# 18415961
